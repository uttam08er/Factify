# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/train.csv')

# %%
df.head()
# Out:
#                                                title  label
# 0   Scientists Confirm Earth is Flat After New Study      0
# 1    President Announces New Economic Relief Package      1
# 2  Eating Chocolate Daily Can Cure Cancer Says Do...      0
# 3  Stock Market Reaches Record High Amid Strong G...      1
# 4  Aliens Found Living in Antarctica Government C...      0

# %%
df.shape
# Out:
# (417, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 417 entries, 0 to 416
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   417 non-null    object
#  1   label   417 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 6.6+ KB

# %%
plt.hist(df['label'])
plt.show()
df['label'].value_counts()
# Out:
# label
# 0    209
# 1    208
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# title    0
# label    0
# dtype: int64

# %%
X_train, X_val, y_train, y_val = train_test_split(df['title'], df['label'], test_size=0.2, random_state=42)

# %%
x_train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 x_train.head()
#
# NameError: name 'x_train' is not defined
